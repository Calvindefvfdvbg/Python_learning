# %%
# -- User input section
#Enter Product 1 -
#Samosa
#Do you Want to add more [Y/N]
# Y
# Enter Product 2 -
# Kachori
# Do you Want to add more [Y/N]
# Y
# Enter Product 3 -
# Fafda
# Do you Want to add more [Y/N]
# Y
# Enter Product 4 -
# Jalebi
# Do you Want to add more [Y/N]
# N
# Enter Samosa Price :
# 300/-
# Enter Kachori Price :
# 100/-
# Enter Fafda Price :
# 100/-
# Enter Jalebi Price :
# 200/-

# Do You Want to add GST [Y/N]
# [note : if user select `N` Print bill without GST]
# [Note User select yes `Y`]
# Enter GST % = 18
# -------Out put -------

# 1. Samosa = 300/-
# 2. Kachori = 100/-
# 3. Fafda = 100/-
# 4. Jalebi = 200/-
# -------------------
# Total = 700
# GST = 18%
# -------------------
# Final Total = 826/-
# -------------------

# %%
products = []
prices = []


count = 1
while True:
    product = input(f"Enter Product {count} -\n")
    products.append(product)

    add_more = input("Do you Want to add more [Y/N]\n").strip().upper()
    if add_more != "Y":
        break
    count += 1


product_price = {}
for product in products:
    price = int(input(f"Enter {product} Price :\n").replace("/-", ""))
    product_price[product] = price


total = sum(product_price.values())


apply_gst = input("Do You Want to add GST [Y/N]\n").strip().upper()
if apply_gst == "Y":
    gst_percent = float(input("Enter GST % = "))
    gst_amount = (total * gst_percent) / 100
    final_total = total + gst_amount
else:
    gst_percent = 0
    final_total = total


print("\n------- Output -------")
for i, (product, price) in enumerate(product_price.items(), start=1):
    print(f"{i}. {product} = {price}/-")

print("-------------------")
print(f"Total = {total}/-")

if apply_gst == "Y":
    print(f"GST = {gst_percent}%")
    print("-------------------")
    print(f"Final Total = {round(final_total)}/-")
    print("-------------------")
else:
    print("-------------------")
    print(f"Final Total = {total}/-")
    print("-------------------")
# Out:
# Enter Product 1 -
#  Pizza
# Do you Want to add more [Y/N]
#  Y
# Enter Product 2 -
#  Pasta
# Do you Want to add more [Y/N]
#  Y
# Enter Product 3 -
#  Sushi
# Do you Want to add more [Y/N]
#  Y
# Enter Product 4 -
#  Ghee
# Do you Want to add more [Y/N]
#  Y
# Enter Product 5 -
#  Pulao
# Do you Want to add more [Y/N]
#  N
# Enter Pizza Price :
#  500
# Enter Pasta Price :
#  100
# Enter Sushi Price :
#  50
# Enter Ghee Price :
#  200
# Enter Pulao Price :
#  450
# Do You Want to add GST [Y/N]
#  Y
# Enter GST % =  18
# ------- Output -------
# 1. Pizza = 500/-
# 2. Pasta = 100/-
# 3. Sushi = 50/-
# 4. Ghee = 200/-
# 5. Pulao = 450/-
# -------------------
# Total = 1300/-
# GST = 18.0%
# -------------------
# Final Total = 1534/-
# -------------------
